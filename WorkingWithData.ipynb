# %% [markdown]
# <a href="https://colab.research.google.com/github/ciriatico/Data-Analytics/blob/master/WorkingWithData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/sample.txt', 'w') as f:
  f.write('Hello Google Drive')
# !cat /content/drive/'My Drive'/sample.txt
# Out:
# Hello Google Drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('drive/My Drive/automobile_data_final.csv')

# %%
print('Shape of the dataset is', data.shape)
# Out:
# Shape of the dataset is (159, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 26 columns):
# symboling            159 non-null int64
# normalized_losses    159 non-null int64
# make                 159 non-null object
# fuel_type            159 non-null object
# aspiration           159 non-null object
# num_of_doors         159 non-null object
# body_style           159 non-null object
# drive_wheels         159 non-null object
# engine_location      159 non-null object
# wheel_base           159 non-null float64
# length               159 non-null float64
# width                159 non-null float64
# height               159 non-null float64
# curb_weight          159 non-null int64
# engine_type          159 non-null object
# num_of_cylinders     159 non-null object
# engine_size          159 non-null int64
# fuel_system          159 non-null object
# bore                 159 non-null float64
# stroke               159 non-null float64
# compression_ratio    159 non-null float64
# horsepower           159 non-null int64
# peak_rpm             159 non-null int64
# city_mpg             159 non-null int64
# highway_mpg          159 non-null int64
# price                159 non-null int64
# dtypes: float64(7), int64(9), object(10)
# memory usage: 32.4+ KB

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
data.make.value_counts().plot(kind='bar', figsize=(15,5))

plt.title('Number of vehicles by make')
plt.ylabel('Number of vehicles')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
data["safe"] = data["symboling"].isin(["-2", "-1", "0"])

# %%
sns.catplot(x = "symboling", y = "city_mpg",
            hue = "safe", data = data,
            dodge = False, kind = "bar", aspect = 1.5)

plt.title("Symboling v/s City mpg")
plt.show()

# %%
sns.lmplot('city_mpg', 'curb_weight',
            data, hue = 'make',
            fit_reg = False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-38e152d3bf5b> in <module>()
#       1 sns.lmplot('city_mpg', 'curb_weight',
#       2             data, hue = 'make',
# ----> 3             fit_reg = False)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     615         scatter_kws=scatter_kws, line_kws=line_kws,
#     616         )
# --> 617     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     618
#     619     # Add a legend
#
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     831
#     832             # Draw the plot
# --> 833             self._facet_plot(func, ax, args, kwargs)
#     834
#     835         # Finalize the annotations and layout
#
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     849
#     850         # Draw the plot
# --> 851         func(*plot_args, **plot_kwargs)
#     852
#     853         # Sort out the supporting information
#
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     808                                  order, logistic, lowess, robust, logx,
#     809                                  x_partial, y_partial, truncate, dropna,
# --> 810                                  x_jitter, y_jitter, color, label)
#     811
#     812     if ax is None:
#
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     112         # Drop null observations
#     113         if dropna:
# --> 114             self.dropna("x", "y", "units", "x_partial", "y_partial")
#     115
#     116         # Regress nuisance variables out of the data
#
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py in dropna(self, *vars)
#      64             val = getattr(self, var)
#      65             if val is not None:
# ---> 66                 setattr(self, var, val[not_na])
#      67
#      68     def plot(self, ax):
#
# IndexError: invalid index to scalar variable.

# %%
# Pacote interativo de gráficos do Colab

import altair as alt

# %%
plot = alt.Chart(data).mark_point().encode(
    x='horsepower',
    y='city_mpg',
    color='body_style').interactive()

# %%
plot
# Out:
# alt.Chart(...)

# %%
interval = alt.selection_interval()

base = alt.Chart(data).mark_point().encode(
         y = 'price',
         color = alt.condition(interval, 'fuel_system',
                               alt.value('lightgray'))).properties(selection=interval)

base.encode(x = 'city_mpg') | base.encode(x = 'horsepower')
# Out:
# alt.HConcatChart(...)

# %%
data = data.drop(['height', 'stroke', 'compression_ratio',
                  'num_of_doors', 'normalized_losses',
                  'engine_location', 'city_mpg'], axis=1)

# %%
# Para lidar com valores categóricos, get_dummies cria colunas boolenas para cada valor categórico

data = pd.get_dummies(data, drop_first=True)

data.head()
# Out:
#    symboling  normalized_losses  ...  fuel_system_mpfi  fuel_system_spdi
# 0          2                164  ...                 1                 0
# 1          2                164  ...                 1                 0
# 2          1                158  ...                 1                 0
# 3          1                158  ...                 1                 0
# 4          2                192  ...                 1                 0
#
# [5 rows x 56 columns]

# %%
data.columns
# Out:
# Index(['symboling', 'make', 'fuel_type', 'aspiration', 'body_style',
#        'drive_wheels', 'wheel_base', 'length', 'width', 'curb_weight',
#        'engine_type', 'num_of_cylinders', 'engine_size', 'fuel_system', 'bore',
#        'horsepower', 'peak_rpm', 'highway_mpg', 'price'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('price', axis=1)
y = data['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106 entries, 69 to 102
# Data columns (total 55 columns):
# symboling                 106 non-null int64
# normalized_losses         106 non-null int64
# wheel_base                106 non-null float64
# length                    106 non-null float64
# width                     106 non-null float64
# height                    106 non-null float64
# curb_weight               106 non-null int64
# engine_size               106 non-null int64
# bore                      106 non-null float64
# stroke                    106 non-null float64
# compression_ratio         106 non-null float64
# horsepower                106 non-null int64
# peak_rpm                  106 non-null int64
# city_mpg                  106 non-null int64
# highway_mpg               106 non-null int64
# safe                      106 non-null bool
# make_bmw                  106 non-null uint8
# make_chevrolet            106 non-null uint8
# make_dodge                106 non-null uint8
# make_honda                106 non-null uint8
# make_jaguar               106 non-null uint8
# make_mazda                106 non-null uint8
# make_mercedes-benz        106 non-null uint8
# make_mitsubishi           106 non-null uint8
# make_nissan               106 non-null uint8
# make_peugot               106 non-null uint8
# make_plymouth             106 non-null uint8
# make_porsche              106 non-null uint8
# make_saab                 106 non-null uint8
# make_subaru               106 non-null uint8
# make_toyota               106 non-null uint8
# make_volkswagen           106 non-null uint8
# make_volvo                106 non-null uint8
# fuel_type_gas             106 non-null uint8
# aspiration_turbo          106 non-null uint8
# num_of_doors_two          106 non-null uint8
# body_style_hardtop        106 non-null uint8
# body_style_hatchback      106 non-null uint8
# body_style_sedan          106 non-null uint8
# body_style_wagon          106 non-null uint8
# drive_wheels_fwd          106 non-null uint8
# drive_wheels_rwd          106 non-null uint8
# engine_type_l             106 non-null uint8
# engine_type_ohc           106 non-null uint8
# engine_type_ohcf          106 non-null uint8
# engine_type_ohcv          106 non-null uint8
# num_of_cylinders_five     106 non-null uint8
# num_of_cylinders_four     106 non-null uint8
# num_of_cylinders_six      106 non-null uint8
# num_of_cylinders_three    106 non-null uint8
# fuel_system_2bbl          106 non-null uint8
# fuel_system_idi           106 non-null uint8
# fuel_system_mfi           106 non-null uint8
# fuel_system_mpfi          106 non-null uint8
# fuel_system_spdi          106 non-null uint8
# dtypes: bool(1), float64(7), int64(8), uint8(39)
# memory usage: 17.4 KB

# %%
model = LinearRegression()

model.fit(X_train, y_train)

pred = model.predict(X_test)

print(mean_absolute_error(y_test, pred))
print(mean_squared_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 1372.035405613207
# 3465620.3056964152
# 0.8718920391506656

# %%
plt.figure(figsize=(10,8))

plt.plot(y_test.values)
plt.plot(pred)
